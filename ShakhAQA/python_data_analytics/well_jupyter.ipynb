# %%
import pandas as pd
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
min_salary = df[('salary_year_avg')].idxmin()

# %%
df.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# salary_year_avg                                                    15000.0
# salary_hour_avg                                                        NaN
# company_name                                               Net2Source Inc.
# job_skills               ['java', 'python', 'oracle', 'aws', 'hadoop', ...
# job_type_skills          {'cloud': ['oracle', 'aws'], 'libraries': ['ha...
# Name: 665729, dtype: object

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df.groupby('job_title_short')

# %%
df.groupby('job_title_short')['job_title_short']

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median(
)
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'median'])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Lesotho                3
# Mauritania             3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Brazil']).any()
# Out:
# np.True_

# %%
df['job_country'].isin(['North Korea']).any()
# Out:
# np.False_

# %%
df['job_country'].isin(['North Korea'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
us_jobs = df[df['job_country'] == "United States"]

# %%
us_jobs
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# 785673                    Asset Management Data Scientist      New York, NY
# 785685                                       Data Analyst  Indianapolis, IN
# 785692               Data Scientist- Hybrid Work Location        Dayton, OH
# 785703            Data Analyst - CRYPTOGRAPHY - Full-time          Anywhere
# 785705          Expert Business Data Analyst - Now Hiring       Oakland, CA
#
#                   job_via         job_schedule_type  job_work_from_home  \
# 0         via Work Nearby                 Full-time               False
# 3       via Diversity.com                 Full-time               False
# 5        via ZipRecruiter  Contractor and Temp work                True
# 6            via LinkedIn                 Full-time               False
# 9        via ZipRecruiter                 Full-time                True
# ...                   ...                       ...                 ...
# 785673    via Trabajo.org                 Full-time               False
# 785685    via Trabajo.org                 Full-time               False
# 785692    via Ai-Jobs.net                 Full-time               False
# 785703       via Snagajob                 Full-time                True
# 785705       via Snagajob                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 0            Texas, United States 2023-06-16 13:44:15                  False
# 3            Texas, United States 2023-07-04 13:01:41                   True
# 5                         Georgia 2023-11-07 14:01:59                  False
# 6          Florida, United States 2023-03-27 13:18:18                  False
# 9         New York, United States 2023-04-23 13:02:57                  False
# ...                           ...                 ...                    ...
# 785673    New York, United States 2023-10-16 06:01:53                   True
# 785685    Illinois, United States 2023-07-16 06:01:27                   True
# 785692    Illinois, United States 2023-04-21 06:02:31                  False
# 785703       Texas, United States 2023-01-28 06:02:55                   True
# 785705  California, United States 2023-01-09 06:00:25                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States        None              NaN
# 3                      False  United States        None              NaN
# 5                      False  United States        None              NaN
# 6                      False  United States        None              NaN
# 9                      False  United States        None              NaN
# ...                      ...            ...         ...              ...
# 785673                 False  United States        None              NaN
# 785685                 False  United States        None              NaN
# 785692                  True  United States        year         157500.0
# 785703                 False  United States        None              NaN
# 785705                 False  United States        None              NaN
#
#         salary_hour_avg                   company_name  \
# 0                   NaN           Boehringer Ingelheim
# 3                   NaN   Southwest Research Institute
# 5                   NaN                smart folks inc
# 6                   NaN  Miracle Software Systems, Inc
# 9                   NaN     Radwell International, LLC
# ...                 ...                            ...
# 785673              NaN           JPMorgan Chase & Co.
# 785685              NaN         Aara Technologies, Inc
# 785692              NaN                         Tenet3
# 785703              NaN    Axelon Services Corporation
# 785705              NaN               PG&E Corporation
#
#                                                job_skills  \
# 0                                                    None
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                ['python', 'sql', 'gcp']
# 6       ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                   ...
# 785673                                               None
# 785685                                   ['sql', 'excel']
# 785692                          ['python', 'matlab', 'r']
# 785703                                               None
# 785705                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills
# 0                                                    None
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5       {'cloud': ['gcp'], 'programming': ['python', '...
# 6       {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9       {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                   ...
# 785673                                               None
# 785685  {'analyst_tools': ['excel'], 'programming': ['...
# 785692         {'programming': ['python', 'matlab', 'r']}
# 785703                                               None
# 785705  {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
us_jobs = us_jobs[us_jobs['salary_hour_avg'].notna()]

# %%
us_jobs
# Out:
#              job_title_short  \
# 43      Senior Data Engineer
# 51      Senior Data Engineer
# 253            Data Engineer
# 294             Data Analyst
# 340             Data Analyst
# ...                      ...
# 783934  Senior Data Engineer
# 784267  Senior Data Engineer
# 785111  Senior Data Engineer
# 785476        Data Scientist
# 785492        Data Scientist
#
#                                                 job_title        job_location  \
# 43      Sr SQL Database Engineer with Data Warehouse /...                None
# 51                                   Senior Data Engineer            Anywhere
# 253                                         Data Engineer            Anywhere
# 294                                 Business/Data Analyst        Hartford, CT
# 340     23-00059 BI Data Analysts + Media experience -...          California
# ...                                                   ...                 ...
# 783934                  Senior Data Engineer - Now Hiring  Rancho Cordova, CA
# 784267             Senior Lead Data Engineer - Now Hiring  Fredericksburg, VA
# 785111  Health and Civil Data Engineer, Senior - Now H...        Bethesda, MD
# 785476                               Data Scientist, Lead      Washington, DC
# 785492                                     Data Scientist       Arlington, VA
#
#              job_via         job_schedule_type  job_work_from_home  \
# 43      via LinkedIn                Contractor               False
# 51      via LinkedIn                Contractor                True
# 253       via Upwork  Contractor and Temp work                True
# 294         via Dice                Contractor               False
# 340     via LinkedIn                Contractor               False
# ...              ...                       ...                 ...
# 783934  via Snagajob                 Full-time               False
# 784267  via Snagajob   Full-time and Part-time               False
# 785111  via Snagajob   Full-time and Part-time               False
# 785476  via Snagajob   Full-time and Part-time               False
# 785492  via Snagajob   Full-time and Part-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 43           Texas, United States 2023-09-13 13:06:55                   True
# 51        Illinois, United States 2023-06-21 13:09:39                  False
# 253                       Georgia 2023-11-26 13:54:45                   True
# 294       New York, United States 2023-07-03 13:00:08                  False
# 340     California, United States 2023-02-28 13:01:46                   True
# ...                           ...                 ...                    ...
# 783934                    Georgia 2023-08-19 06:44:33                  False
# 784267  California, United States 2023-11-13 06:03:59                  False
# 785111                    Georgia 2023-10-08 06:50:59                  False
# 785476                    Georgia 2023-11-01 06:58:10                  False
# 785492                    Georgia 2023-11-01 06:58:02                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 43                     False  United States        hour              NaN
# 51                     False  United States        hour              NaN
# 253                    False  United States        hour              NaN
# 294                    False  United States        hour              NaN
# 340                    False  United States        hour              NaN
# ...                      ...            ...         ...              ...
# 783934                  True  United States        hour              NaN
# 784267                  True  United States        hour              NaN
# 785111                  True  United States        hour              NaN
# 785476                  True  United States        hour              NaN
# 785492                  True  United States        hour              NaN
#
#         salary_hour_avg            company_name  \
# 43            97.500000                  Phaxis
# 51            72.500000        Aditi Consulting
# 253           88.000000                  Upwork
# 294           52.500000  Vector Consulting, Inc
# 340           67.500000            iSpace, Inc.
# ...                 ...                     ...
# 783934        53.285000              VSP Vision
# 784267        61.159996             Capital One
# 785111        61.159996     Booz Allen Hamilton
# 785476        47.620003     Booz Allen Hamilton
# 785492        47.620003     Booz Allen Hamilton
#
#                                                job_skills  \
# 43                                  ['sql', 'sql server']
# 51       ['python', 'java', 'aws', 'databricks', 'spark']
# 253     ['sql', 'python', 'java', 'mysql', 'postgresql...
# 294                                                  None
# 340     ['go', 'sql', 'aws', 'snowflake', 'tableau', '...
# ...                                                   ...
# 783934  ['sql', 'oracle', 'aws', 'snowflake', 'redshif...
# 784267  ['java', 'scala', 'python', 'nosql', 'sql', 'm...
# 785111  ['python', 'sql', 'scala', 'java', 'shell', 'n...
# 785476                     ['databricks', 'azure', 'aws']
# 785492                         ['python', 'r', 'pyspark']
#
#                                           job_type_skills
# 43      {'databases': ['sql server'], 'programming': [...
# 51      {'cloud': ['aws', 'databricks'], 'libraries': ...
# 253     {'cloud': ['aws', 'gcp'], 'databases': ['mysql...
# 294                                                  None
# 340     {'analyst_tools': ['tableau', 'looker', 'word'...
# ...                                                   ...
# 783934  {'analyst_tools': ['ssis'], 'cloud': ['oracle'...
# 784267  {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 785111  {'cloud': ['aws', 'azure', 'databricks', 'reds...
# 785476          {'cloud': ['databricks', 'azure', 'aws']}
# 785492  {'libraries': ['pyspark'], 'programming': ['py...
#
# [9405 rows x 17 columns]

# %%
us_jobs.groupby('job_title_short').count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                 354           352      354
# Cloud Engineer                    14            14       14
# Data Analyst                    3980          3944     3973
# Data Engineer                   1876          1863     1876
# Data Scientist                  2100          2090     2100
# Machine Learning Engineer         30            30       30
# Senior Data Analyst              341           336      341
# Senior Data Engineer             361           357      361
# Senior Data Scientist            278           277      278
# Software Engineer                 71            71       71
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                         346                 354
# Cloud Engineer                            14                  14
# Data Analyst                            3893                3980
# Data Engineer                           1868                1876
# Data Scientist                          2091                2100
# Machine Learning Engineer                 30                  30
# Senior Data Analyst                      338                 341
# Senior Data Engineer                     361                 361
# Senior Data Scientist                    277                 278
# Software Engineer                         69                  71
#
#                            search_location  job_posted_date  \
# job_title_short
# Business Analyst                       354              354
# Cloud Engineer                          14               14
# Data Analyst                          3980             3980
# Data Engineer                         1876             1876
# Data Scientist                        2100             2100
# Machine Learning Engineer               30               30
# Senior Data Analyst                    341              341
# Senior Data Engineer                   361              361
# Senior Data Scientist                  278              278
# Software Engineer                       71               71
#
#                            job_no_degree_mention  job_health_insurance  \
# job_title_short
# Business Analyst                             354                   354
# Cloud Engineer                                14                    14
# Data Analyst                                3980                  3980
# Data Engineer                               1876                  1876
# Data Scientist                              2100                  2100
# Machine Learning Engineer                     30                    30
# Senior Data Analyst                          341                   341
# Senior Data Engineer                         361                   361
# Senior Data Scientist                        278                   278
# Software Engineer                             71                    71
#
#                            job_country  salary_rate  salary_year_avg  \
# job_title_short
# Business Analyst                   354          354                0
# Cloud Engineer                      14           14                0
# Data Analyst                      3980         3980                0
# Data Engineer                     1876         1876                0
# Data Scientist                    2100         2100                0
# Machine Learning Engineer           30           30                0
# Senior Data Analyst                341          341                0
# Senior Data Engineer               361          361                0
# Senior Data Scientist              278          278                0
# Software Engineer                   71           71                0
#
#                            salary_hour_avg  company_name  job_skills  \
# job_title_short
# Business Analyst                       354           354         297
# Cloud Engineer                          14            14           9
# Data Analyst                          3980          3980        3369
# Data Engineer                         1876          1876        1774
# Data Scientist                        2100          2100        1784
# Machine Learning Engineer               30            30          26
# Senior Data Analyst                    341           341         312
# Senior Data Engineer                   361           361         349
# Senior Data Scientist                  278           278         250
# Software Engineer                       71            71          61
#
#                            job_type_skills
# job_title_short
# Business Analyst                       297
# Cloud Engineer                           9
# Data Analyst                          3369
# Data Engineer                         1774
# Data Scientist                        1784
# Machine Learning Engineer               26
# Senior Data Analyst                    312
# Senior Data Engineer                   349
# Senior Data Scientist                  250
# Software Engineer                       61

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].min()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                       NaN
# Cloud Engineer                         NaN
# Data Analyst                           NaN
# Data Engineer                          NaN
# Data Scientist                         NaN
# Machine Learning Engineer              NaN
# Senior Data Analyst                    NaN
# Senior Data Engineer                   NaN
# Senior Data Scientist                  NaN
# Software Engineer                      NaN

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].min()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                       NaN
# Cloud Engineer                         NaN
# Data Analyst                           NaN
# Data Engineer                          NaN
# Data Scientist                         NaN
# Machine Learning Engineer              NaN
# Senior Data Analyst                    NaN
# Senior Data Engineer                   NaN
# Senior Data Scientist                  NaN
# Software Engineer                      NaN

# %%
us_jobs = us_jobs[us_jobs['salary_hour_avg'].notna()]

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].min()
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                       NaN
# Cloud Engineer                         NaN
# Data Analyst                           NaN
# Data Engineer                          NaN
# Data Scientist                         NaN
# Machine Learning Engineer              NaN
# Senior Data Analyst                    NaN
# Senior Data Engineer                   NaN
# Senior Data Scientist                  NaN
# Software Engineer                      NaN

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].agg(['min', 'max', 'median'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 us_jobs.groupby('job_title_short')[['salary_year_avg']].agg(['min', 'max', 'median'])
#
# NameError: name 'us_jobs' is not defined
