# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df.sample(10)
# Out:
#              job_title_short                            job_title  \
# 247946  Senior Data Engineer           (USA) Senior Data Engineer
# 730842        Data Scientist                Junior Data Scientist
# 729699      Business Analyst        Business Intelligence Analyst
# 542024          Data Analyst                       Data Analyst 2
# 353044   Senior Data Analyst  Manager - Engineering Data Analysis
# 598786         Data Engineer                    Big Data Engineer
# 336586  Senior Data Engineer                 Senior Data Engineer
# 388918      Business Analyst                              Analyst
# 468438      Business Analyst             Senior Analyst, Bookings
# 127691         Data Engineer                   Big Data Developer
#
#                                  job_location               job_via  \
# 247946                        Bentonville, AR           via Ladders
# 730842                           Cádiz, Spain             via BeBee
# 729699                         United Kingdom          via LinkedIn
# 542024                                  India       via BeBee India
# 353044                     Salt Lake City, UT             via BeBee
# 598786                            West Bengal          via LinkedIn
# 336586                         United Kingdom  via Jobs Trabajo.org
# 388918                              Hong Kong       via Trabajo.org
# 468438  Heredia Province, Heredia, Costa Rica  via BeBee Costa Rica
# 127691                               Anywhere          via LinkedIn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 247946         Full-time               False                      Sudan
# 730842         Full-time               False                      Spain
# 729699         Full-time               False             United Kingdom
# 542024         Full-time               False                      India
# 353044         Full-time               False  California, United States
# 598786         Full-time               False                      India
# 336586         Full-time               False             United Kingdom
# 388918         Full-time               False                  Hong Kong
# 468438         Full-time               False                 Costa Rica
# 127691        Contractor                True                      India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 247946 2023-08-26 07:55:47                  False                  True
# 730842 2023-08-29 21:42:26                  False                 False
# 729699 2023-09-05 21:15:09                   True                 False
# 542024 2023-10-16 19:30:33                  False                 False
# 353044 2023-09-09 23:02:20                  False                  True
# 598786 2023-06-27 09:35:37                   True                 False
# 336586 2023-01-18 23:17:27                   True                 False
# 388918 2023-07-19 18:21:44                  False                 False
# 468438 2023-07-15 14:31:24                   True                 False
# 127691 2023-02-11 08:14:05                   True                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 247946           Sudan        year         125000.0              NaN
# 730842           Spain        None              NaN              NaN
# 729699  United Kingdom        None              NaN              NaN
# 542024           India        None              NaN              NaN
# 353044   United States        None              NaN              NaN
# 598786           India        None              NaN              NaN
# 336586  United Kingdom        None              NaN              NaN
# 388918       Hong Kong        None              NaN              NaN
# 468438      Costa Rica        None              NaN              NaN
# 127691           India        None              NaN              NaN
#
#                          company_name  \
# 247946                        Walmart
# 730842               Moffatt & Nichol
# 729699                Williams Racing
# 542024                Bread Financial
# 353044  Northrop Grumman Corporations
# 598786                            IBM
# 336586                         Veolia
# 388918        Zung Fu Company Limited
# 468438                         VMware
# 127691                    CodersBrain
#
#                                                job_skills  \
# 247946  ['sql', 't-sql', 'tableau', 'power bi', 'looker']
# 730842  ['r', 'python', 'c', 'c++', 'java', 'javascrip...
# 729699                            ['power bi', 'tableau']
# 542024  ['sql', 'express', 'word', 'excel', 'powerpoint']
# 353044                                               None
# 598786  ['sql', 'python', 'gcp', 'bigquery', 'ibm clou...
# 336586         ['sql', 'databricks', 'azure', 'power bi']
# 388918                                  ['excel', 'word']
# 468438                                  ['vmware', 'sap']
# 127691  ['java', 'sql', 'nosql', 'cassandra', 'couchdb...
#
#                                           job_type_skills
# 247946  {'analyst_tools': ['tableau', 'power bi', 'loo...
# 730842  {'cloud': ['redshift', 'digitalocean'], 'datab...
# 729699         {'analyst_tools': ['power bi', 'tableau']}
# 542024  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 353044                                               None
# 598786  {'analyst_tools': ['looker', 'tableau'], 'clou...
# 336586  {'analyst_tools': ['power bi'], 'cloud': ['dat...
# 388918               {'analyst_tools': ['excel', 'word']}
# 468438    {'analyst_tools': ['sap'], 'cloud': ['vmware']}
# 127691  {'async': ['jira'], 'cloud': ['aws'], 'databas...

# %%
# MISS YOUUUUUUUU

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# 780907              Data Engineer with Fivetran,Qlik Must
#
#                      job_location                 job_via job_schedule_type  \
# 502901                St Paul, MN               via BeBee         Full-time
# 406337                 London, UK            via LinkedIn         Full-time
# 659951    Newcastle upon Tyne, UK              via Indeed         Full-time
# 541593                      Malta         via Trabajo.org         Full-time
# 425158     Amsterdam, Netherlands          via NBC4i Jobs         Full-time
# 183426                  Singapore  via Singapore | JobsDB         Full-time
# 287790                  Tampa, FL            via LinkedIn         Full-time
# 541983              Chantilly, VA      via Clearance Jobs         Full-time
# 416896                     France            via LinkedIn         Full-time
# 780907  Mexico City, CDMX, Mexico        via BeBee México         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
# 183426               False               Singapore 2023-11-09 16:07:57
# 287790               False  Florida, United States 2023-07-14 17:02:23
# 541983               False                 Georgia 2023-06-15 19:44:34
# 416896               False                  France 2023-09-22 16:47:24
# 780907               False                  Mexico 2023-01-16 06:19:09
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
# 183426                  False                 False       Singapore
# 287790                   True                 False   United States
# 541983                  False                 False   United States
# 416896                  False                 False          France
# 780907                  False                 False          Mexico
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
# 183426        None              NaN              NaN    FLEXOSENSE PTE. LTD.
# 287790        None              NaN              NaN      Iris Software Inc.
# 541983        None              NaN              NaN                    SAIC
# 416896        None              NaN              NaN             KPMG France
# 780907        None              NaN              NaN        CORUS Consulting
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
# 183426  ['r', 'python', 'java', 'sql', 'sql server', '...
# 287790                         ['sql', 'hadoop', 'excel']
# 541983  ['sql', 'r', 'matlab', 'python', 'oracle', 'aw...
# 416896                                               None
# 780907  ['oracle', 'snowflake', 'aws', 'azure', 'alter...
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
# 183426  {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 287790  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 541983  {'analyst_tools': ['power bi', 'tableau', 'qli...
# 416896                                               None
# 780907  {'analyst_tools': ['alteryx'], 'cloud': ['orac...

# %%
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()

# %%
median_salary
# Out:
# np.float64(115000.0)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 2811955004000

# %%
id(df_altered)
# Out:
# 2811955004000

# %%
id(df_altered) == id(df_original)
# Out:
# True

# %%
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('Id of df_original    ', id(df_original))
print('Id of df_altered   ', id(df_altered))
# Out:
# Id of df_original     2809603645728
# Id of df_altered    2811541440080

# %% [markdown]
# df = dataset['train'].to_pandas()

# %%
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.pivot_table(index='job_title_short', aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.groupby('job_title_short').size().sort_values(ascending=False)
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# dtype: int64

# %%
df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.pivot_table(values='salary_year_avg', columns='job_country',index='job_title_short', aggfunc='mean')
# Out:
# job_country                  Albania  Algeria      Argentina   Armenia  \
# job_title_short
# Business Analyst                 NaN      NaN   71100.000000       NaN
# Cloud Engineer                   NaN      NaN  197500.000000       NaN
# Data Analyst                49950.00  44100.0   85436.375000  100500.0
# Data Engineer                    NaN  45000.0   94276.846154   48750.0
# Data Scientist              69981.25      NaN   99536.916667       NaN
# Machine Learning Engineer        NaN      NaN  131009.666667   87021.0
# Senior Data Analyst              NaN      NaN            NaN       NaN
# Senior Data Engineer             NaN      NaN  147500.000000       NaN
# Senior Data Scientist      157500.00      NaN            NaN       NaN
# Software Engineer                NaN      NaN  174500.000000       NaN
#
# job_country                    Australia    Austria  Azerbaijan  \
# job_title_short
# Business Analyst            87666.666667        NaN         NaN
# Cloud Engineer             110000.000000        NaN         NaN
# Data Analyst               102875.000000   94624.00         NaN
# Data Engineer              112479.983333  135000.00         NaN
# Data Scientist             139755.857143   71249.75         NaN
# Machine Learning Engineer  122304.142857   89100.00         NaN
# Senior Data Analyst         50640.000000   89100.00         NaN
# Senior Data Engineer       119894.000000  132900.00         NaN
# Senior Data Scientist      157500.000000   80850.00         NaN
# Software Engineer          140655.833333        NaN     72000.0
#
# job_country                      Bahamas  Bangladesh   Belarus  ...   Uganda  \
# job_title_short                                                 ...
# Business Analyst                     NaN     16500.0       NaN  ...      NaN
# Cloud Engineer                       NaN         NaN       NaN  ...      NaN
# Data Analyst                         NaN         NaN  400000.0  ...  69300.0
# Data Engineer              219405.500000     97444.0       NaN  ...      NaN
# Data Scientist                       NaN         NaN       NaN  ...  84200.0
# Machine Learning Engineer  228750.000000     69000.0       NaN  ...      NaN
# Senior Data Analyst                  NaN         NaN       NaN  ...      NaN
# Senior Data Engineer       183928.571429         NaN       NaN  ...      NaN
# Senior Data Scientist                NaN         NaN       NaN  ...      NaN
# Software Engineer          182875.000000         NaN       NaN  ...  44100.0
#
# job_country                      Ukraine  United Arab Emirates  \
# job_title_short
# Business Analyst            72900.000000                   NaN
# Cloud Engineer              89100.000000                   NaN
# Data Analyst                74509.416667              91875.00
# Data Engineer               95139.000000             125498.75
# Data Scientist             113098.833333             166419.50
# Machine Learning Engineer   93612.571429              62850.00
# Senior Data Analyst                  NaN             105337.50
# Senior Data Engineer        96773.000000                   NaN
# Senior Data Scientist      157500.000000              72000.00
# Software Engineer           54000.000000              79200.00
#
# job_country                United Kingdom  United States   Uruguay  \
# job_title_short
# Business Analyst             49560.000000   96175.447397       NaN
# Cloud Engineer                        NaN  120090.900000       NaN
# Data Analyst                 89410.916667   94553.964924  100500.0
# Data Engineer               115622.200000  134226.676753       NaN
# Data Scientist              110250.933333  139946.707204       NaN
# Machine Learning Engineer   139564.428571  154240.382812   50000.0
# Senior Data Analyst         107314.375000  115729.129954       NaN
# Senior Data Engineer        137550.020833  151448.023186       NaN
# Senior Data Scientist       129399.225806  159330.432029   57500.0
# Software Engineer           103280.000000  137964.929588       NaN
#
# job_country                Uzbekistan        Vietnam   Zambia  Zimbabwe
# job_title_short
# Business Analyst                  NaN   74400.000000      NaN       NaN
# Cloud Engineer                    NaN            NaN      NaN       NaN
# Data Analyst                      NaN   90842.454545      NaN   63000.0
# Data Engineer                     NaN   98508.187500      NaN       NaN
# Data Scientist                30750.0   89066.666667  90670.0   69085.0
# Machine Learning Engineer         NaN   71381.250000      NaN       NaN
# Senior Data Analyst               NaN  100512.500000      NaN       NaN
# Senior Data Engineer              NaN  127125.000000      NaN       NaN
# Senior Data Scientist             NaN   79200.000000      NaN       NaN
# Software Engineer                 NaN   53600.000000      NaN       NaN
#
# [10 rows x 108 columns]

# %%
top_countries = df['job_country'].value_counts().head(6).index
df_job_country_salary = df.pivot_table(
    values='salary_year_avg',
    index='job_country',
    columns='job_title_short',
    aggfunc='median'
)

df_job_country_salary = df_job_country_salary.loc[top_countries]

job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

df_job_country_salary = df_job_country_salary[job_titles]

df_job_country_salary.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df_job_country_salary.plot(kind='bar')
plt.ylabel('Median Salary (USD)')
plt.xlabel('')
plt.title('Median Salary by Country and Job title')
plt.xticks(rotation=45, ha='right')
plt.show()
